# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayakpotdar2114/Daily-Assignemnts/blob/main/Assignment_Week_4_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 1. How do you choose a machine learning algorithm for a problem statement?
# ## Explain Briefly.

# %% [markdown]
# In order to select the machine learning model, we need to start with the data. If the data is labelled then, it will be a supervised learning model.If the data is not labelled, it will be a unsupervised learning model.
#
# Moving ahead we can focus on the statement itself, if the statement wants us to get the output in terms of continuous data, it will be a regression problem. If the output is to be divided in to classes, it will be a classification algorithm.
# If the model is supposed to be divided into multiple clusters, it will be a clustering algorithm.

# %% [markdown]
# ## 2. What is Semi- Supervised Learning and why is it so important?

# %% [markdown]
# An algorithm where the data that we are using has a large amount of unlabelled data and some small portion of labelled data is called Semi Supervised Algorithm.

# %% [markdown]
# ## 3. Why we can’t do a classification problem using Regression?

# %% [markdown]
# Classification problems are solved using either discriminative or generative algorithms. Either we are trying to find a boundry or a threshold value for classifying the data. In regression problems we are trying to predict the output based on the previously fed datapoints.
# If we use regression method,we break the fundamental requirement of regression which is the presence of continuous data.
# If we use regression the shift in the threshold will cause issues.

# %% [markdown]
# ## 4. How do you treat heteroscedasticity in regression? What causes Heteroscedasticity and how to fix it?

# %% [markdown]
# Heteroscedasticity is the presence of outliers in the data the affect the variance of the data.
# To reduce Heteroscedasticity, we can transform the dependent variable using some transformation method like log transform.
# To reduct the Heteroscedasticity in regression problems, we can use weighted regression that penalizes the outliers.

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 5. Let X be a discrete random variable with the following PMF.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-09-19 at 11.08.27 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 6. Let X and Y be two independent random variables. Suppose that we know Var(2X−Y)=6 and Var(X+2Y)=9. Find Var(X) and Var(Y).

# %% [markdown]
# ![WhatsApp Image 2022-09-19 at 11.08.09 AM.jpeg](data:image/jpeg;base64,...)
